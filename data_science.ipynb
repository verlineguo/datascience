# %% [markdown]
# <a href="https://colab.research.google.com/github/verlineguo/datascience/blob/main/data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Classification Algorithm A

# %% [markdown]
# ### Classification Algorithm B

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion
